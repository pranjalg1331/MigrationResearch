# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %%
df=pd.read_csv('/content/02.csv',delimiter=";",index_col=None, header=0)

# %%
df=df.drop(['CPU cores','Disk size [GB]','CPU capacity provisioned [MHZ]','Network received throughput [KB/s]','Network transmitted throughput [KB/s]','CPU usage [MHZ]','Memory capacity provisioned [KB]','Memory usage [KB]','Memory usage [%]','Disk read throughput [KB/s]','Disk write throughput [KB/s]'],axis=1)

# %%
df['Datetime'] = pd.to_datetime(df['Timestamp'], format='%d.%m.%Y %H:%M:%S')
df=df.drop(['Timestamp'],axis=1)

# %%
df.head()
# Out:
#   CPU usage [%]            Datetime
# 0           2,5 2015-11-05 00:00:00
# 1          2,71 2015-11-05 00:05:00
# 2          2,48 2015-11-05 00:10:00
# 3          2,62 2015-11-05 00:15:00
# 4          2,44 2015-11-05 00:20:00

# %%
df['CPU usage [%]'] = df['CPU usage [%]'].str.replace(',', '.').astype(float)
# df['Memory usage [%]'] = df['Memory usage [%]'].str.replace(',', '.').astype(float)
df.head()
# Out:
#    CPU usage [%]            Datetime
# 0           2.50 2015-11-05 00:00:00
# 1           2.71 2015-11-05 00:05:00
# 2           2.48 2015-11-05 00:10:00
# 3           2.62 2015-11-05 00:15:00
# 4           2.44 2015-11-05 00:20:00

# %%
df['CPU_10_min_before'] = df['CPU usage [%]'].shift(1)
df['CPU_20_min_before'] = df['CPU usage [%]'].shift(2)
df['CPU_30_min_before'] = df['CPU usage [%]'].shift(3)
df['hour']=df['Datetime'].dt.hour
df['dayofweek']=df['Datetime'].dt.dayofweek
df['dayodyear']=df['Datetime'].dt.dayofyear
df=df.drop(['Datetime'],axis=1)
df=df.dropna()
df.head()
# Out:
#    CPU usage [%]  CPU_10_min_before  CPU_20_min_before  CPU_30_min_before  \
# 3           2.62               2.48               2.71               2.50
# 4           2.44               2.62               2.48               2.71
# 5           2.45               2.44               2.62               2.48
# 6           2.61               2.45               2.44               2.62
# 7           2.42               2.61               2.45               2.44
#
#    hour  dayofweek  dayodyear
# 3     0          3        309
# 4     0          3        309
# 5     0          3        309
# 6     0          3        309
# 7     0          3        309

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
train_size = int(len(df) * 0.8)
train_df = df[:train_size]
test_df = df[train_size:]
X_train=train_df.drop(columns=['CPU usage [%]'])
y_train=train_df['CPU usage [%]']
X_test=test_df.drop(columns=['CPU usage [%]'])
y_test=test_df['CPU usage [%]']
# test_df.head()

# %%
X_train.head()
# Out:
#    CPU_10_min_before  CPU_20_min_before  CPU_30_min_before  hour  dayofweek  \
# 3           0.004796           0.007144           0.005001     0          3
# 4           0.006225           0.004796           0.007144     0          3
# 5           0.004388           0.006225           0.004796     0          3
# 6           0.004490           0.004388           0.006225     0          3
# 7           0.006123           0.004490           0.004388     0          3
#
#    dayodyear
# 3        309
# 4        309
# 5        309
# 6        309
# 7        309

# %%
import xgboost as xgb

# %%
reg=xgb.XGBRegressor(n_estimators=1000,early_stopping_round=50 )

# %%
reg.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_test,y_test)],
       verbose=True)
# y_pred=rfc.predict(X_test)
# Out:
# [0]	validation_0-rmse:0.07157	validation_1-rmse:0.31622
# [1]	validation_0-rmse:0.05133	validation_1-rmse:0.31581
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [06:16:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "early_stopping_round" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [2]	validation_0-rmse:0.03731	validation_1-rmse:0.23751
# [3]	validation_0-rmse:0.02731	validation_1-rmse:0.23728
# [4]	validation_0-rmse:0.02039	validation_1-rmse:0.23711
# [5]	validation_0-rmse:0.01590	validation_1-rmse:0.20805
# [6]	validation_0-rmse:0.01270	validation_1-rmse:0.21758
# [7]	validation_0-rmse:0.01061	validation_1-rmse:0.19566
# [8]	validation_0-rmse:0.00926	validation_1-rmse:0.18039
# [9]	validation_0-rmse:0.00845	validation_1-rmse:0.18231
# [10]	validation_0-rmse:0.00801	validation_1-rmse:0.18384
# [11]	validation_0-rmse:0.00770	validation_1-rmse:0.18533
# [12]	validation_0-rmse:0.00749	validation_1-rmse:0.17926
# [13]	validation_0-rmse:0.00730	validation_1-rmse:0.17441
# [14]	validation_0-rmse:0.00723	validation_1-rmse:0.17678
# [15]	validation_0-rmse:0.00715	validation_1-rmse:0.17972
# [16]	validation_0-rmse:0.00704	validation_1-rmse:0.18222
# [17]	validation_0-rmse:0.00701	validation_1-rmse:0.18434
# [18]	validation_0-rmse:0.00695	validation_1-rmse:0.18528
# [19]	validation_0-rmse:0.00690	validation_1-rmse:0.18543
# [20]	validation_0-rmse:0.00687	validation_1-rmse:0.18533
# [21]	validation_0-rmse:0.00677	validation_1-rmse:0.18540
# [22]	validation_0-rmse:0.00670	validation_1-rmse:0.18618
# [23]	validation_0-rmse:0.00664	validation_1-rmse:0.18629
# [24]	validation_0-rmse:0.00660	validation_1-rmse:0.18643
# [25]	validation_0-rmse:0.00657	validation_1-rmse:0.18640
# [26]	validation_0-rmse:0.00652	validation_1-rmse:0.18639
# [27]	validation_0-rmse:0.00651	validation_1-rmse:0.18643
# [28]	validation_0-rmse:0.00647	validation_1-rmse:0.18642
# [29]	validation_0-rmse:0.00642	validation_1-rmse:0.18749
# [30]	validation_0-rmse:0.00639	validation_1-rmse:0.18840
# [31]	validation_0-rmse:0.00636	validation_1-rmse:0.18854
# [32]	validation_0-rmse:0.00635	validation_1-rmse:0.18894
# [33]	validation_0-rmse:0.00633	validation_1-rmse:0.18897
# [34]	validation_0-rmse:0.00630	validation_1-rmse:0.18896
# [35]	validation_0-rmse:0.00629	validation_1-rmse:0.18911
# [36]	validation_0-rmse:0.00624	validation_1-rmse:0.18923
# [37]	validation_0-rmse:0.00624	validation_1-rmse:0.18837
# [38]	validation_0-rmse:0.00622	validation_1-rmse:0.18850
# [39]	validation_0-rmse:0.00622	validation_1-rmse:0.18849
# [40]	validation_0-rmse:0.00621	validation_1-rmse:0.18848
# [41]	validation_0-rmse:0.00620	validation_1-rmse:0.18797
# [42]	validation_0-rmse:0.00618	validation_1-rmse:0.18813
# [43]	validation_0-rmse:0.00618	validation_1-rmse:0.18752
# [44]	validation_0-rmse:0.00617	validation_1-rmse:0.18751
# [45]	validation_0-rmse:0.00616	validation_1-rmse:0.18751
# [46]	validation_0-rmse:0.00616	validation_1-rmse:0.18732
# [47]	validation_0-rmse:0.00614	validation_1-rmse:0.18732
# [48]	validation_0-rmse:0.00614	validation_1-rmse:0.18732
# [49]	validation_0-rmse:0.00613	validation_1-rmse:0.18733
# [50]	validation_0-rmse:0.00611	validation_1-rmse:0.18742
# [51]	validation_0-rmse:0.00610	validation_1-rmse:0.18741
# [52]	validation_0-rmse:0.00609	validation_1-rmse:0.18743
# [53]	validation_0-rmse:0.00608	validation_1-rmse:0.18742
# [54]	validation_0-rmse:0.00607	validation_1-rmse:0.18743
# [55]	validation_0-rmse:0.00606	validation_1-rmse:0.18743
# [56]	validation_0-rmse:0.00604	validation_1-rmse:0.18725
# [57]	validation_0-rmse:0.00604	validation_1-rmse:0.18723
# [58]	validation_0-rmse:0.00604	validation_1-rmse:0.18726
# [59]	validation_0-rmse:0.00604	validation_1-rmse:0.18726
# [60]	validation_0-rmse:0.00603	validation_1-rmse:0.18726
# [61]	validation_0-rmse:0.00602	validation_1-rmse:0.18727
# [62]	validation_0-rmse:0.00601	validation_1-rmse:0.18728
# [63]	validation_0-rmse:0.00601	validation_1-rmse:0.18729
# [64]	validation_0-rmse:0.00600	validation_1-rmse:0.18747
# [65]	validation_0-rmse:0.00598	validation_1-rmse:0.18746
# [66]	validation_0-rmse:0.00597	validation_1-rmse:0.18746
# [67]	validation_0-rmse:0.00596	validation_1-rmse:0.18738
# [68]	validation_0-rmse:0.00595	validation_1-rmse:0.18738
# [69]	validation_0-rmse:0.00595	validation_1-rmse:0.18739
# [70]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [71]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [72]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [73]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [74]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [75]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [76]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [77]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [78]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [79]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [80]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [81]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [82]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [83]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [84]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [85]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [86]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [87]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [88]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [89]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [90]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [91]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [92]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [93]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [94]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [95]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [96]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [97]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [98]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [99]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [100]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [101]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [102]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [103]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [104]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [105]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [106]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [107]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [108]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [109]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [110]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [111]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [112]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [113]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [114]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [115]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [116]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [117]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [118]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [119]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [120]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [121]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [122]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [123]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [124]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [125]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [126]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [127]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [128]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [129]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [130]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [131]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [132]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [133]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [134]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [135]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [136]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [137]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [138]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [139]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [140]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [141]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [142]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [143]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [144]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [145]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [146]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [147]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [148]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [149]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [150]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [151]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [152]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [153]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [154]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [155]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [156]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [157]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [158]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [159]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [160]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [161]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [162]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [163]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [164]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [165]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [166]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [167]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [168]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [169]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [170]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [171]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [172]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [173]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [174]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [175]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [176]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [177]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [178]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [179]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [180]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [181]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [182]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [183]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [184]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [185]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [186]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [187]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [188]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [189]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [190]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [191]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [192]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [193]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [194]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [195]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [196]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [197]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [198]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [199]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [200]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [201]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [202]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [203]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [204]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [205]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [206]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [207]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [208]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [209]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [210]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [211]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [212]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [213]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [214]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [215]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [216]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [217]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [218]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [219]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [220]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [221]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [222]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [223]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [224]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [225]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [226]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [227]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [228]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [229]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [230]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [231]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [232]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [233]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [234]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [235]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [236]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [237]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [238]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [239]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [240]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [241]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [242]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [243]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [244]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [245]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [246]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [247]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [248]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [249]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [250]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [251]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [252]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [253]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [254]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [255]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [256]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [257]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [258]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [259]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [260]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [261]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [262]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [263]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [264]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [265]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [266]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [267]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [268]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [269]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [270]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [271]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [272]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [273]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [274]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [275]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [276]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [277]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [278]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [279]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [280]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [281]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [282]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [283]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [284]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [285]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [286]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [287]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [288]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [289]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [290]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [291]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [292]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [293]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [294]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [295]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [296]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [297]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [298]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [299]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [300]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [301]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [302]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [303]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [304]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [305]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [306]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [307]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [308]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [309]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [310]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [311]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [312]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [313]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [314]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [315]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [316]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [317]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [318]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [319]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [320]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [321]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [322]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [323]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [324]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [325]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [326]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [327]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [328]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [329]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [330]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [331]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [332]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [333]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [334]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [335]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [336]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [337]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [338]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [339]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [340]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [341]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [342]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [343]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [344]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [345]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [346]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [347]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [348]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [349]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [350]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [351]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [352]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [353]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [354]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [355]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [356]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [357]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [358]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [359]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [360]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [361]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [362]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [363]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [364]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [365]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [366]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [367]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [368]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [369]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [370]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [371]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [372]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [373]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [374]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [375]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [376]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [377]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [378]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [379]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [380]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [381]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [382]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [383]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [384]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [385]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [386]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [387]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [388]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [389]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [390]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [391]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [392]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [393]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [394]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [395]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [396]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [397]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [398]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [399]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [400]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [401]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [402]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [403]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [404]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [405]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [406]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [407]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [408]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [409]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [410]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [411]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [412]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [413]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [414]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [415]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [416]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [417]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [418]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [419]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [420]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [421]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [422]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [423]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [424]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [425]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [426]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [427]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [428]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [429]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [430]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [431]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [432]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [433]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [434]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [435]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [436]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [437]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [438]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [439]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [440]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [441]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [442]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [443]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [444]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [445]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [446]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [447]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [448]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [449]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [450]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [451]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [452]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [453]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [454]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [455]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [456]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [457]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [458]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [459]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [460]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [461]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [462]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [463]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [464]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [465]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [466]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [467]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [468]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [469]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [470]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [471]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [472]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [473]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [474]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [475]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [476]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [477]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [478]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [479]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [480]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [481]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [482]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [483]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [484]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [485]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [486]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [487]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [488]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [489]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [490]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [491]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [492]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [493]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [494]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [495]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [496]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [497]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [498]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [499]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [500]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [501]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [502]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [503]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [504]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [505]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [506]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [507]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [508]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [509]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [510]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [511]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [512]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [513]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [514]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [515]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [516]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [517]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [518]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [519]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [520]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [521]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [522]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [523]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [524]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [525]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [526]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [527]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [528]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [529]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [530]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [531]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [532]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [533]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [534]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [535]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [536]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [537]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [538]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [539]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [540]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [541]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [542]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [543]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [544]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [545]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [546]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [547]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [548]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [549]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [550]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [551]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [552]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [553]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [554]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [555]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [556]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [557]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [558]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [559]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [560]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [561]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [562]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [563]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [564]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [565]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [566]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [567]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [568]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [569]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [570]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [571]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [572]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [573]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [574]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [575]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [576]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [577]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [578]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [579]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [580]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [581]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [582]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [583]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [584]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [585]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [586]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [587]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [588]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [589]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [590]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [591]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [592]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [593]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [594]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [595]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [596]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [597]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [598]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [599]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [600]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [601]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [602]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [603]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [604]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [605]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [606]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [607]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [608]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [609]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [610]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [611]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [612]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [613]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [614]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [615]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [616]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [617]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [618]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [619]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [620]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [621]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [622]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [623]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [624]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [625]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [626]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [627]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [628]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [629]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [630]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [631]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [632]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [633]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [634]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [635]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [636]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [637]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [638]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [639]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [640]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [641]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [642]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [643]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [644]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [645]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [646]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [647]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [648]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [649]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [650]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [651]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [652]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [653]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [654]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [655]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [656]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [657]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [658]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [659]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [660]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [661]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [662]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [663]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [664]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [665]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [666]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [667]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [668]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [669]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [670]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [671]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [672]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [673]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [674]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [675]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [676]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [677]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [678]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [679]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [680]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [681]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [682]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [683]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [684]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [685]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [686]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [687]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [688]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [689]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [690]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [691]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [692]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [693]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [694]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [695]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [696]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [697]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [698]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [699]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [700]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [701]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [702]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [703]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [704]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [705]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [706]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [707]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [708]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [709]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [710]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [711]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [712]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [713]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [714]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [715]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [716]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [717]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [718]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [719]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [720]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [721]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [722]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [723]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [724]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [725]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [726]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [727]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [728]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [729]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [730]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [731]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [732]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [733]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [734]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [735]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [736]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [737]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [738]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [739]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [740]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [741]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [742]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [743]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [744]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [745]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [746]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [747]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [748]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [749]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [750]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [751]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [752]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [753]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [754]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [755]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [756]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [757]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [758]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [759]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [760]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [761]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [762]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [763]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [764]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [765]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [766]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [767]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [768]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [769]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [770]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [771]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [772]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [773]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [774]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [775]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [776]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [777]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [778]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [779]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [780]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [781]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [782]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [783]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [784]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [785]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [786]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [787]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [788]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [789]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [790]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [791]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [792]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [793]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [794]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [795]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [796]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [797]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [798]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [799]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [800]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [801]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [802]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [803]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [804]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [805]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [806]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [807]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [808]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [809]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [810]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [811]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [812]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [813]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [814]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [815]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [816]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [817]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [818]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [819]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [820]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [821]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [822]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [823]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [824]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [825]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [826]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [827]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [828]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [829]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [830]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [831]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [832]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [833]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [834]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [835]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [836]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [837]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [838]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [839]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [840]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [841]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [842]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [843]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [844]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [845]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [846]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [847]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [848]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [849]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [850]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [851]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [852]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [853]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [854]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [855]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [856]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [857]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [858]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [859]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [860]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [861]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [862]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [863]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [864]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [865]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [866]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [867]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [868]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [869]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [870]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [871]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [872]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [873]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [874]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [875]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [876]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [877]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [878]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [879]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [880]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [881]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [882]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [883]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [884]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [885]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [886]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [887]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [888]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [889]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [890]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [891]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [892]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [893]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [894]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [895]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [896]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [897]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [898]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [899]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [900]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [901]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [902]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [903]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [904]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [905]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [906]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [907]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [908]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [909]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [910]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [911]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [912]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [913]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [914]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [915]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [916]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [917]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [918]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [919]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [920]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [921]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [922]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [923]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [924]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [925]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [926]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [927]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [928]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [929]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [930]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [931]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [932]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [933]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [934]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [935]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [936]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [937]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [938]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [939]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [940]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [941]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [942]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [943]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [944]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [945]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [946]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [947]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [948]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [949]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [950]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [951]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [952]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [953]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [954]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [955]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [956]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [957]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [958]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [959]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [960]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [961]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [962]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [963]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [964]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [965]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [966]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [967]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [968]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [969]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [970]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [971]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [972]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [973]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [974]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [975]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [976]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [977]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [978]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [979]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [980]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [981]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [982]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [983]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [984]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [985]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [986]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [987]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [988]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [989]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [990]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [991]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [992]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [993]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [994]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [995]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [996]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [997]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [998]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# [999]	validation_0-rmse:0.00595	validation_1-rmse:0.18741
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_round=50,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred=reg.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
r2 = r2_score(y_test, y_pred)

mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)

# Print the metrics
print(f"R-squared: {r2:.4f}")
print(f"Mean Absolute Error: {mae:.4f}")
print(f"Mean Squared Error: {mse:.4f}")
print(f"Root Mean Squared Error: {rmse:.4f}")
# Out:
# R-squared: 0.4836
# Mean Absolute Error: 0.1130
# Mean Squared Error: 0.0351
# Root Mean Squared Error: 0.1874

# %%
plt.plot(y_test.index, y_test, label='True CPU Usage')
plt.plot(y_test.index, y_pred, label='Predicted CPU Usage')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Instantiate the RandomForestRegressor
rf = RandomForestRegressor(n_estimators=1000)

# Fit the model
rf.fit(X_train, y_train)

# Make predictions
y_pred_rf = rf.predict(X_test)

# Evaluate the model
r2_rf = r2_score(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)

print(f"Random Forest - R-squared: {r2_rf:.4f}")
print(f"Random Forest - Mean Absolute Error: {mae_rf:.4f}")
print(f"Random Forest - Root Mean Squared Error: {rmse_rf:.4f}")
# Out:
# Random Forest - R-squared: 0.9168
# Random Forest - Mean Absolute Error: 0.0456
# Random Forest - Root Mean Squared Error: 0.0752

# %%
plt.plot(y_test.index, y_test, label='True CPU Usage')
plt.plot(y_test.index, y_pred_rf, label='Predicted CPU Usage')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Instantiate the GradientBoostingRegressor
gbr = GradientBoostingRegressor(n_estimators=1000)

# Fit the model
gbr.fit(X_train, y_train)

# Make predictions
y_pred_gbr = gbr.predict(X_test)

# Evaluate the model
r2_gbr = r2_score(y_test, y_pred_gbr)
mae_gbr = mean_absolute_error(y_test, y_pred_gbr)
mse_gbr = mean_squared_error(y_test, y_pred_gbr)
rmse_gbr = np.sqrt(mse_gbr)

print(f"Gradient Boosting - R-squared: {r2_gbr:.4f}")
print(f"Gradient Boosting - Mean Absolute Error: {mae_gbr:.4f}")
print(f"Gradient Boosting - Root Mean Squared Error: {rmse_gbr:.4f}")
# Out:
# Gradient Boosting - R-squared: 0.6135
# Gradient Boosting - Mean Absolute Error: 0.0969
# Gradient Boosting - Root Mean Squared Error: 0.1621

# %%
# Evaluate the model
r2_gbr = r2_score(y_test, y_pred_gbr)
mae_gbr = mean_absolute_error(y_test, y_pred_gbr)
mse_gbr = mean_squared_error(y_test, y_pred_gbr)
rmse_gbr = np.sqrt(mse_gbr)

print(f"Gradient Boosting - R-squared: {r2_gbr:.4f}")
print(f"Gradient Boosting - Mean Absolute Error: {mae_gbr:.4f}")
print(f"Gradient Boosting - Root Mean Squared Error: {rmse_gbr:.4f}")
# Out:
# Gradient Boosting - R-squared: 0.6135
# Gradient Boosting - Mean Absolute Error: 0.0969
# Gradient Boosting - Root Mean Squared Error: 0.1621

# %%
plt.plot(y_test.index, y_test, label='True CPU Usage')
plt.plot(y_test.index, y_pred_gbr, label='Predicted CPU Usage')
plt.legend()
plt.show()

# %%
  from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)  # You can tune the number of neighbors

# Fit the model
knn.fit(X_train, y_train)

# Make predictions
y_pred_knn = knn.predict(X_test)

# %%
r2_knn = r2_score(y_test, y_pred_knn)
mae_knn = mean_absolute_error(y_test, y_pred_knn)
mse_knn = mean_squared_error(y_test, y_pred_knn)
rmse_knn = np.sqrt(mse_knn)

print(f"KNN - R-squared: {r2_knn:.4f}")
print(f"KNN - Mean Absolute Error: {mae_knn:.4f}")
print(f"KNN - Root Mean Squared Error: {rmse_knn:.4f}")
# Out:
# KNN - R-squared: -0.5246
# KNN - Mean Absolute Error: 0.1921
# KNN - Root Mean Squared Error: 0.3220

# %%
plt.plot(y_test.index, y_test, label='True CPU Usage')
plt.plot(y_test.index, y_pred_knn, label='Predicted CPU Usage')
plt.legend()
plt.show()

# %%
import lightgbm as lgb
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
lgb_reg = lgb.LGBMRegressor(n_estimators=1000)

# Fit the model
lgb_reg.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)])

# Make predictions
y_pred_lgb = lgb_reg.predict(X_test)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 539
# [LightGBM] [Info] Number of data points in the train set: 6679, number of used features: 6
# [LightGBM] [Info] Start training from score 0.016976

# %%
plt.plot(y_test.index, y_test, label='True CPU Usage')
plt.plot(y_test.index, y_pred_lgb, label='Predicted CPU Usage')
plt.legend()
plt.show()

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import VotingRegressor, StackingRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor


# Initialize individual models
xgb_model = XGBRegressor(n_estimators=1000)
rf_model = RandomForestRegressor(n_estimators=1000)
gbr_model = GradientBoostingRegressor(n_estimators=1000)
knn_model = KNeighborsRegressor(n_neighbors=5)
lgb_model = LGBMRegressor(n_estimators=1000)

# %%
from sklearn.ensemble import VotingRegressor, StackingRegressor
# Create the voting regressor
voting_reg = VotingRegressor(estimators=[
    ('xgb', xgb_model),
    ('rf', rf_model),
    ('gbr', gbr_model),
    ('knn', knn_model),
    ('lgb', lgb_model)
])

# Train the voting regressor
voting_reg.fit(X_train, y_train)

# Make predictions with the voting regressor
y_pred_voting = voting_reg.predict(X_test)

# Evaluate the voting model
r2_voting = r2_score(y_test, y_pred_voting)
mae_voting = mean_absolute_error(y_test, y_pred_voting)
rmse_voting = np.sqrt(mean_squared_error(y_test, y_pred_voting))

print(f"Voting Regressor - R-squared: {r2_voting:.4f}")
print(f"Voting Regressor - Mean Absolute Error: {mae_voting:.4f}")
print(f"Voting Regressor - Root Mean Squared Error: {rmse_voting:.4f}")

plt.plot(y_test.index, y_test, label='True CPU Usage')
plt.plot(y_test.index, y_pred_voting, label='Predicted CPU Usage')
plt.legend()
plt.show()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000786 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 539
# [LightGBM] [Info] Number of data points in the train set: 6679, number of used features: 6
# [LightGBM] [Info] Start training from score 0.016976
# Voting Regressor - R-squared: 0.6380
# Voting Regressor - Mean Absolute Error: 0.0941
# Voting Regressor - Root Mean Squared Error: 0.1569

# %%
# Create the stacking regressor
stacking_reg = StackingRegressor(
    estimators=[
        ('xgb', xgb_model),
        ('rf', rf_model),
        ('gbr', gbr_model),
        ('knn', knn_model),
        ('lgb', lgb_model)
    ],
    final_estimator=Ridge()  # The meta-model (you can use any other regressor)
)

# Train the stacking regressor
stacking_reg.fit(X_train, y_train)

# Make predictions with the stacking regressor
y_pred_stacking = stacking_reg.predict(X_test)

# Evaluate the stacking model
r2_stacking = r2_score(y_test, y_pred_stacking)
mae_stacking = mean_absolute_error(y_test, y_pred_stacking)
rmse_stacking = np.sqrt(mean_squared_error(y_test, y_pred_stacking))

print(f"Stacking Regressor - R-squared: {r2_stacking:.4f}")
print(f"Stacking Regressor - Mean Absolute Error: {mae_stacking:.4f}")
print(f"Stacking Regressor - Root Mean Squared Error: {rmse_stacking:.4f}")

plt.plot(y_test.index, y_test, label='True CPU Usage')
plt.plot(y_test.index, y_pred_stacking, label='Predicted CPU Usage')
plt.legend()
plt.show()
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 539
# [LightGBM] [Info] Number of data points in the train set: 6679, number of used features: 6
# [LightGBM] [Info] Start training from score 0.016976
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000134 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 520
# [LightGBM] [Info] Number of data points in the train set: 5343, number of used features: 6
# [LightGBM] [Info] Start training from score 0.019831
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000565 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 523
# [LightGBM] [Info] Number of data points in the train set: 5343, number of used features: 6
# [LightGBM] [Info] Start training from score 0.019938
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 536
# [LightGBM] [Info] Number of data points in the train set: 5343, number of used features: 6
# [LightGBM] [Info] Start training from score 0.019921
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000394 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 5343, number of used features: 6
# [LightGBM] [Info] Start training from score 0.005887
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000129 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 453
# [LightGBM] [Info] Number of data points in the train set: 5344, number of used features: 6
# [LightGBM] [Info] Start training from score 0.019302
# Stacking Regressor - R-squared: 0.3728
# Stacking Regressor - Mean Absolute Error: 0.1189
# Stacking Regressor - Root Mean Squared Error: 0.2065

# %% [markdown]
# Blending

# %%
from sklearn.model_selection import train_test_split

# Split the training data into two parts for blending
X_blend_train, X_blend_meta, y_blend_train, y_blend_meta = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Train the base models on X_blend_train
xgb_model = XGBRegressor(n_estimators=1000)
rf_model = RandomForestRegressor(n_estimators=1000)
gbr_model = GradientBoostingRegressor(n_estimators=1000)
knn_model = KNeighborsRegressor(n_neighbors=5)
lgb_model = LGBMRegressor(n_estimators=1000)

xgb_model.fit(X_blend_train, y_blend_train)
rf_model.fit(X_blend_train, y_blend_train)
gbr_model.fit(X_blend_train, y_blend_train)
knn_model.fit(X_blend_train, y_blend_train)
lgb_model.fit(X_blend_train, y_blend_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 503
# [LightGBM] [Info] Number of data points in the train set: 5343, number of used features: 6
# [LightGBM] [Info] Start training from score 0.016259
# LGBMRegressor(n_estimators=1000)

# %%
# Generate meta-features (predictions) for the meta-model using X_blend_meta
meta_features = np.column_stack([
    xgb_model.predict(X_blend_meta),
    rf_model.predict(X_blend_meta),
    gbr_model.predict(X_blend_meta),
    knn_model.predict(X_blend_meta),
    lgb_model.predict(X_blend_meta)
])

# %%
from sklearn.linear_model import Ridge

# Train the meta-model on the meta-features
meta_model = Ridge()
meta_model.fit(meta_features, y_blend_meta)
# Out:
# Ridge()

# %%
# Generate base model predictions on the test set
meta_features_test = np.column_stack([
    xgb_model.predict(X_test),
    rf_model.predict(X_test),
    gbr_model.predict(X_test),
    knn_model.predict(X_test),
    lgb_model.predict(X_test)
])

# Use the meta-model to make final predictions on the test set
y_pred_blending = meta_model.predict(meta_features_test)

# %%
# Evaluate the blending model
r2_blending = r2_score(y_test, y_pred_blending)
mae_blending = mean_absolute_error(y_test, y_pred_blending)
rmse_blending = np.sqrt(mean_squared_error(y_test, y_pred_blending))

print(f"Blending - R-squared: {r2_blending:.4f}")
print(f"Blending - Mean Absolute Error: {mae_blending:.4f}")
print(f"Blending - Root Mean Squared Error: {rmse_blending:.4f}")

plt.plot(y_test.index, y_test, label='True CPU Usage')
plt.plot(y_test.index, y_pred_blending, label='Blended Predicted CPU Usage')
plt.legend()
plt.show()
# Out:
# Blending - R-squared: 0.1341
# Blending - Mean Absolute Error: 0.1459
# Blending - Root Mean Squared Error: 0.2427
